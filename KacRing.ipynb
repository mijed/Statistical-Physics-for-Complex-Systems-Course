# %% [markdown]
# # Mark Kac - Ring Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import random



def simulation_step(tab):
    previous_tabs = balls.copy()
    for i in range(len(balls)):
        balls[i] = previous_tabs[i-1] * markers[i - 1]

# %%
# Size of the Ring
N = 500

# Probability of a marker being on a given edge
u = 0.009


time_range = 2*N


plt.figure(figsize=(12,4))
avg = np.zeros(2*N)
N_avg = 400
for trajectory in range(N_avg):
    # 1 - Black ball, -1 - White ball
    balls = [1]*N
    markers = random.choices([-1, 1], weights=[u, 1-u], k=N)
    result = np.zeros(time_range)
    for t in range(time_range):
        result[t] += (balls.count(1) - balls.count(-1))
        simulation_step(balls)

    avg += result
    plt.subplot(121)
    plt.plot(range(time_range), result)
    plt.title(f"Trajectories N = {N}")
    plt.xlabel("Time")
    plt.ylabel("B(t) - W(t)")
    


plt.subplot(122)
plt.plot(range(time_range), avg/400)
plt.title(f"Average of {N_avg} trajectories ")
plt.xlabel("Time")
plt.show()

# %% [markdown]
#  N = 1000

# %%
# Size of the Ring
N = 1000

# Probability of a marker being on a given edge
u = 0.009


time_range = 2*N


plt.figure(figsize=(12,4))
avg = np.zeros(2*N)
N_avg = 400
for trajectory in range(N_avg):
    # 1 - Black ball, -1 - White ball
    balls = [1]*N
    markers = random.choices([-1, 1], weights=[u, 1-u], k=N)
    result = np.zeros(time_range)
    for t in range(time_range):
        result[t] += (balls.count(1) - balls.count(-1))
        simulation_step(balls)

    avg += result
    plt.subplot(121)
    plt.plot(range(time_range), result)
    plt.title(f"Trajectories N = {N}")
    plt.xlabel("Time")
    plt.ylabel("B(t) - W(t)")
    


plt.subplot(122)
plt.plot(range(time_range), avg/400)
plt.title(f"Average of {N_avg} trajectories ")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# N = 2000

# %%
# Size of the Ring
N = 2000

# Probability of a marker being on a given edge
u = 0.009


time_range = 2*N


plt.figure(figsize=(12,4))
avg = np.zeros(2*N)
N_avg = 400
for trajectory in range(N_avg):
    # 1 - Black ball, -1 - White ball
    balls = [1]*N
    markers = random.choices([-1, 1], weights=[u, 1-u], k=N)
    result = np.zeros(time_range)
    for t in range(time_range):
        result[t] += (balls.count(1) - balls.count(-1))
        simulation_step(balls)

    avg += result
    plt.subplot(121)
    plt.plot(range(time_range), result)
    plt.title(f"Trajectories N = {N}")
    plt.xlabel("Time")
    plt.ylabel("B(t) - W(t)")
    


plt.subplot(122)
plt.plot(range(time_range), avg/400)
plt.title(f"Average of {N_avg} trajectories ")
plt.xlabel("Time")
plt.show()
